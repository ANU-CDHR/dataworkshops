# %% [markdown]
# 2.1 Getting data via web scraping Wikipedia page
# ======

# %% [markdown]
# **In this section we demonstrate how to scrape data from Wikipedia page and url. Wikipedia python library is used first to do a simple query of Wikipedia page and create a wold cloud. BeautifulSoup python library is then used to demostrate more complex example to scrape data from page table in Wikipeida url and save to file. Lastly we show how to scrape different language versions of the same Wikipedia page and create word cloud for that language.**

# %% [markdown]
# 2.1.1 Using Wikipedia python library
# ------
# **Search Wikipedia page and get page content data.**

# %%
# import Wikipedia python library
import wikipedia

# %% [markdown]
# **Search Exploration under Wikipeida. The code below is equivalent to entering Exploration in the search box at https://www.wikipedia.org/ and search. It returns page on https://en.wikipedia.org/wiki/Exploration.**

# %%
# access Explorer Wikipedia page
page = wikipedia.page('Exploration')

# %% [markdown]
# **Get plain text content of the page, excluding images, tables, and other data.**

# %%
#Get plain text content of the page, excluding images, tables, and other data.
content = page.content

# %%
#print(content)

# %%
# import Regular Expression python library
import re

# %% [markdown]
# **Clean page content remove symbols and changing line.**

# %%
# clean page content remove symbols and changing line
content = re.sub(r'==.*?==+', '', content)
content = content.replace('\n', '')
print(content)
# Out:
# Exploration is the act of searching for the purpose of discovery of information or resources. Exploration occurs in all non-sessile animal species, including humans. In human history, its most dramatic rise was during the Age of Discovery when European explorers sailed and charted much of the rest of the world for a variety of reasons. Since then, major explorations after the Age of Discovery have occurred for reasons mostly aimed at information discovery.The Phoenicians (1550 BCE–300 BCE) traded throughout the Mediterranean Sea and Asia Minor though many of their routes are still unknown today. The presence of tin in some Phoenician artifacts suggests that they may have traveled to Britain. According to Virgil's Aeneid and other ancient sources, the legendary Queen Dido was a Phoenician from Tyre who sailed to North Africa and founded the city of Carthage. Carthaginean exploration of Western Africa Hanno the Navigator (500 BC), a Carthaginean navigator who explored the Western Coast of Africa.The Greek explorer from Marseille, Pytheas (380 – c. 310 BC) was the first to circumnavigate Great Britain, explore Germany, and reach Thule (most commonly thought to be the Shetland Islands or Iceland).Romans -under Augustus emperor- reached and explored all the Baltic SeaAfrica ExplorationThe Romans organized expeditions to cross the Sahara desert with five different routes:through the western Sahara, toward the Niger river and actual Timbuktu.through the Tibesti mountains, toward Lake Chad and actual Nigeriathrough the Nile river, toward actual Uganda.though the western coast of Africa, toward the Canary Islands and the Cape Verde islands.through the Red Sea, toward actual Somalia and perhaps Tanzania.All these expeditions were supported by legionaries and had mainly a commercial purpose. Only the one done by emperor Nero seemed to be a preparative for the conquest of Ethiopia or Nubia: in 62 AD two legionaries explored the sources of the Nile river.One of the main reasons of the explorations was to get gold using the camel to transport it.The explorations near the African western and eastern coasts were supported by Roman ships and deeply related to the naval commerce (mainly toward the Indian Ocean).The Romans also organized several explorations into Northern Europe, and explored as far as China in Asia.30 BC-640 ADWith the acquisition of Ptolemaic Egypt, The Romans begin trading with India. The Empire now has a direct connection to the Spice trade Egypt had established beginning in 118 BC.100 AD-166 ADRomano-Chinese relations begin. Ptolemy writes of the Golden Chersonese (i.e. Malay Peninsula) and the trade port of Kattigara, now identified as Óc Eo in northern Vietnam, then part of Jiaozhou, a province of the Chinese Han Empire. The Chinese historical texts describe Roman embassies, from a land they called Daqin.2nd centuryRoman traders reach Siam, Cambodia, Sumatra, and Java.161An embassy from Roman Emperor Antoninus Pius or his successor Marcus Aurelius reaches Chinese Emperor Huan of Han at Luoyang.226A Roman diplomat or merchant lands in northern Vietnam and visits Nanjing, China and the court of Sun Quan, ruler of Eastern WuDuring the 2nd century BC, the Han dynasty explored much of the Eastern Northern Hemisphere. Starting in 139 BC, the Han diplomat Zhang Qian traveled west in an unsuccessful attempt to secure an alliance with the Da Yuezhi against the Xiongnu (the Yuezhi had been evicted from Gansu by the Xiongnu in 177 BC); however, Zhang's travels discovered entire countries which the Chinese were unaware of, including the remnants of the conquests of Alexander the Great (r. 336–323 BC). When Zhang returned to China in 125 BC, he reported on his visits to Dayuan (Fergana), Kangju (Sogdiana), and Daxia (Bactria, formerly the Greco-Bactrian Kingdom which had just been subjugated by the Da Yuezhi). Zhang described Dayuan and Daxia as agricultural and urban countries like China, and although he did not venture there, descri ...

# %% [markdown]
# **Try a simple wordcloud with page content.**

# %%
# try wordcloud with page content
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# **Remove stopwords and generate wordcloud content.**

# %%
# remove stopwords and generate wordcloud content
wordcloud = WordCloud(stopwords=STOPWORDS).generate(content)

# %% [markdown]
# **Plot the simple wordcloud.**

# %%
# import python plot graph library
import matplotlib.pyplot as plt
# show wordcloud
plt.figure(figsize = (10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# 2.1.2 Using BeautifulSoup python library to get data
# ------
# **Get data from Wikipedia page table via url request. Get list of explorers from https://en.wikipedia.org/wiki/List_of_explorers which contain explorer names, nationalities, centuries and main areas explored.**

# %%
# import BeautifulSoup and other reqired libraries
from bs4 import BeautifulSoup
import requests
import os
import codecs

# %%
# set Wikipedia page url to be scraped
url="https://en.wikipedia.org/wiki/List_of_explorers"

# %% [markdown]
# **Get page via url request.**

# %%
# access page via url request
wikipage = requests.get(url)

# %% [markdown]
# **Create BeautifulSoup object with page content.**

# %%
# create BeautifulSoup object with page content
soup = BeautifulSoup(wikipage.content)

# %% [markdown]
# **Find all tables in the page.**

# %%
# find all tables in the page
tables = soup.findAll("table", {"class": "wikitable"})

# %% [markdown]
# **Show table.**

# %%
# show tables
for i, table in enumerate(tables):
    # print table number
    print("#"*10 + "Table {}".format(i) + '#'*10)
    # print first 50 text
    print(table.text[:50])
    # print divider
    print('.'*80)
print("#"*80)
# Out:
# ##########Table 0##########
#
#
# Name
#
# Modern (and former) nationality
#
# Centuries
# ................................................................................
# ################################################################################

# %% [markdown]
# **Create function to export TSVs (tab-separated values file) from Wiki page tables.**

# %%
# export CSVs from Wiki page tables
def exportWikiTB(Url, tables):
    for tn, table in enumerate(tables):

        # preinit list of lists
        rows = table.findAll("tr")
        row_lengths = [len(r.findAll(['th', 'td'])) for r in rows]
        ncols = max(row_lengths)
        nrows = len(rows)
        data = []
        for i in range(nrows):
            rowD = []
            for j in range(ncols):
                rowD.append('')
            data.append(rowD)

        # process html
        for i in range(len(rows)):
            row = rows[i]
            rowD = []
            cells = row.findAll(["td", "th"])
            for j in range(len(cells)):
                cell = cells[j]

                #lots of cells span cols and rows so lets deal with that
                cspan = int(cell.get('colspan', 1))
                rspan = int(cell.get('rowspan', 1))
                l = 0
                for k in range(rspan):
                    # Shifts to the first empty cell of this row
                    while data[i + k][j + l]:
                        l += 1
                    for m in range(cspan):
                        cell_n = j + l + m
                        row_n = i + k
                        # in some cases the colspan can overflow the table, in those cases just get the last item
                        cell_n = min(cell_n, len(data[row_n])-1)
                        data[row_n][cell_n] += cell.text
                        #print(cell.text)

            data.append(rowD)

        # write data out to tab seperated format
        page = os.path.split(url)[1]
        fname = 'output_{}_t{}.tsv'.format(page, tn)
        f = codecs.open(fname, 'w')
        for i in range(nrows):
            rowStr = '\t'.join(data[i])
            rowStr = rowStr.replace('\n', '')
            #print(rowStr)
            f.write(rowStr + '\n')

        f.close()

# %% [markdown]
# **Run the function to export TSV file.**

# %%
exportWikiTB(url, tables)

# %% [markdown]
# 2.1.3 Create wordcloud from page and create function for wordclouds from different languages version of Wikipedia pages.
# ------

# %%
# import Regular Expression python library
import re

# %%
# set Wikipedia page url to be scraped
url="https://en.wikipedia.org/wiki/Democracy"

# %% [markdown]
# **Get page via url request.**

# %%
# access page via url request
wikipage = requests.get(url)

# %% [markdown]
# **Create BeautifulSoup object with page content.**

# %%
# create BeautifulSoup object with page content
soup = BeautifulSoup(wikipage.text)

# %% [markdown]
# **Clean page content remove symbols and changing line.**

# %%
# select paragraphs
paragraphs = soup.select('p')
paragraphs = [paragraph.text for paragraph in paragraphs]
# remove [] citation sybmols from text
paragraphs = [re.sub(r'\[\d+\]','',paragraph.strip())  for paragraph in paragraphs if paragraph.strip() != '']
# clean page content remove symbols and changing line
content = re.sub(r'==.*?==+', '', " ".join(paragraphs))
content = content.replace('\n', '')
#print(content)

# %% [markdown]
# **Try a simple wordcloud with page content.**

# %%
# try wordcloud with page content
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# **Remove stopwords and generate wordcloud content.**

# %%
# remove stopwords and generate wordcloud content
wordcloud = WordCloud(stopwords=STOPWORDS).generate(content)

# %% [markdown]
# **Plot the simple wordcloud.**

# %%
# import python plot graph library
import matplotlib.pyplot as plt
# show wordcloud
plt.figure(figsize = (10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **Combine all above and create the function to plot wordcloud from Wikipeida url.**

# %%
from bs4 import BeautifulSoup
import requests
import os
import re
import codecs
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import nltk
#nltk.download()
from nltk.corpus import stopwords
#import spacy 


# define function to plot wordcloud from Wikipeida url
def wiki_cloud(url,lang="english", **kwargs):
    # access page via url request
    wikipage = requests.get(url)
    # create BeautifulSoup object with page content
    soup = BeautifulSoup(wikipage.text)
    # select paragraphs
    paragraphs = soup.select('p')
    paragraphs = [paragraph.text for paragraph in paragraphs]
    # remove [] citation sybmols from text
    paragraphs = [re.sub(r'\[\d+\]','',paragraph.strip())  for paragraph in paragraphs if paragraph.strip() != '']
    # clean page content remove symbols and changing line
    content = re.sub(r'==.*?==+', '', " ".join(paragraphs))
    content = content.replace('\n', '')
    #print(content)
    #use different language stopwords
    nltk_sw = stopwords.words(lang)
    #nlp = spacy.load('es_core_web_sm')


    # remove stopwords and generate wordcloud content
    wordcloud = WordCloud(stopwords=nltk_sw, **kwargs).generate(content)
    # show wordcloud
    plt.figure(figsize = (10,10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
url="https://en.wikipedia.org/wiki/Democracy"
wiki_cloud(url,'english')

# %% [markdown]
# **Find other language versions of the same Wikipedia page under the languages menu on the left side of the page.**

# %%
#Portuguese version of the Wikipedia page
url="https://pt.wikipedia.org/wiki/Democracia"
wiki_cloud(url, 'portuguese')

# %%
#Spanish version of the Wikipedia page
url="https://es.wikipedia.org/wiki/Democracia"
wiki_cloud(url, 'spanish')

# %%
#Chinese version of the Wikipedia page
url="https://zh.wikipedia.org/wiki/%E6%B0%91%E4%B8%BB"
#Use different font for the Chinese version of the word cloud
font_filename = 'fonts/STFangSong.ttf'
wiki_cloud(url, 'chinese',font_path=font_filename)

# %% [markdown]
# References:
# ------

# %% [markdown]
# [Scrape Wikipedia tables by wassname](https://gist.github.com/wassname)

# %% [markdown]
# [Two simple ways to scrape text from Wikipedia in Python](https://levelup.gitconnected.com/two-simple-ways-to-scrape-text-from-wikipedia-in-python-9ce07426579b)
